# %% [markdown]
# # Create a subset of NACTI training data

# %%
import json
import pandas as pd
from shutil import copyfile
import os
import re
import numpy as np

# %% [markdown]
# Import the data

# %%
nacti_json = '/data/nacti/nacti_metadata.json'

with open(nacti_json) as f:
    data = json.loads(f.read())

# %% [markdown]
# Create mappings for category id to category name and image id to image filename

# %%
category_map = {cat['id']:re.sub(' |-', '_', cat['common name']) for cat in data['categories']}

# %%
id_path_map = {img['id']:img['file_name'] for img in data['images']}

# %% [markdown]
# Create a list of species important to our analysis

# %%
species_list = [
    'american_black_bear', 
    'bobcat', 
    'coyote', 
    'empty', 
    'vehicle', 
    'cougar', 
    'human', 
    'dog', 
    'white_tailed_deer',
    'wolf',
    'moose',
    'gray_fox',
    'elk',
    'domestic_dog',
    'wild_turkey',
    'red_fox',
    'domestic_cow'
]

# %%
len(species_list)
# Out:
# 17

# %% [markdown]
# ### Create a dataframe of labeled data

# %%
# Import annotations
df = pd.DataFrame(data['annotations'])
# Get the file path for each image id
df['file_path'] = df['image_id'].apply(lambda x: id_path_map[x])
# Get the category name for each category id
df['category_name'] = df['category_id'].apply(lambda x: category_map[x])
# Get the current subfolder that the file is located in
df['subfolder'] = df['file_path'].apply(lambda x: re.findall('sub\d{3}', x)[0])
df.head()
# Out:
#    category_id                                    id  \
# 0           10  b56989c2-d98a-11e8-969f-000d3a71ec1a
# 1           10  b56989c3-d98a-11e8-969f-000d3a71ec1a
# 2           10  b56989c4-d98a-11e8-969f-000d3a71ec1a
# 3           10  b56989c5-d98a-11e8-969f-000d3a71ec1a
# 4           10  b56989c6-d98a-11e8-969f-000d3a71ec1a
#
#                            image_id                                file_path  \
# 0  2010_Unit150_Ivan097_img0001.jpg  sub001/2010_Unit150_Ivan097_img0001.jpg
# 1  2010_Unit150_Ivan097_img0002.jpg  sub001/2010_Unit150_Ivan097_img0002.jpg
# 2  2010_Unit150_Ivan097_img0003.jpg  sub001/2010_Unit150_Ivan097_img0003.jpg
# 3  2010_Unit150_Ivan097_img0004.jpg  sub001/2010_Unit150_Ivan097_img0004.jpg
# 4  2010_Unit150_Ivan097_img0005.jpg  sub001/2010_Unit150_Ivan097_img0005.jpg
#
#   category_name subfolder
# 0      red_deer    sub001
# 1      red_deer    sub001
# 2      red_deer    sub001
# 3      red_deer    sub001
# 4      red_deer    sub001

# %% [markdown]
# Get only the species that are necessary for our analysis

# %%
# Get species that are in our species list
subset = df[df['category_name'].isin(species_list)]

# Get species with at least 100 observations
# sample_count = (subset.groupby(['category_name'])['id'].nunique() > 100).to_dict()
# subset = subset[subset['category_name'].apply(lambda x: sample_count[x])]

# %%
subset.groupby(['category_name'])['id'].nunique()
# Out:
# category_name
# american_black_bear      88478
# bobcat                   25443
# cougar                   14756
# coyote                   21946
# domestic_cow           2019012
# domestic_dog               752
# elk                      22143
# empty                   460135
# gray_fox                 10230
# moose                     9964
# red_fox                   1723
# vehicle                  26015
# white_tailed_deer        13598
# wild_turkey               4366
# wolf                       474
# Name: id, dtype: int64

# %% [markdown]
# ### Split the data

# %%
def apply_train_test_dev_labels(value, splits):
    label = []
    for i in range(value):
        if i < value*splits[0]:
            label += ['train']
        elif (i >= value*splits[0]) and (i < value*(splits[1] + splits[0])):
            label += ['val']
        else:
            label += ['test']
    return label

# %%
max_val = 100000
list_ = []
splits = (0.7, 0.15, 0.15)

for key, grp in subset.groupby(['category_name']):
    samp_size = len(grp)
    grp = grp.sample(frac=1).reset_index(drop=True)
    if samp_size > max_val:
        grp = grp.iloc[:max_val]
        samp_size = max_val
    grp['set'] = apply_train_test_dev_labels(samp_size, splits)
    list_.append(grp)

shuff_df = pd.concat(list_).reset_index(drop=True)
shuff_df['new_path'] = '/data/training_data/' + shuff_df['set'] + '/' + shuff_df['category_name'] + '/'  + shuff_df['image_id']
shuff_df['old_path'] = '/data/nacti/' + shuff_df['file_path']
shuff_df['dir_name'] = shuff_df['new_path'].apply(lambda x: os.path.dirname(x))

# %%
shuff_df.groupby(['set', 'category_name'])['id'].nunique()
# Out:
# set    category_name
# test   american_black_bear    13271
#        bobcat                  3816
#        cougar                  2213
#        coyote                  3291
#        domestic_cow           15000
#        domestic_dog             112
#        elk                     3321
#        empty                  15000
#        gray_fox                1534
#        moose                   1494
#        red_fox                  258
#        vehicle                 3902
#        white_tailed_deer       2039
#        wild_turkey              654
#        wolf                      71
# train  american_black_bear    61935
#        bobcat                 17811
#        cougar                 10330
#        coyote                 15363
#        domestic_cow           70000
#        domestic_dog             527
#        elk                    15501
#        empty                  70000
#        gray_fox                7161
#        moose                   6975
#        red_fox                 1207
#        vehicle                18211
#        white_tailed_deer       9519
#        wild_turkey             3057
#        wolf                     332
# val    american_black_bear    13272
#        bobcat                  3816
#        cougar                  2213
#        coyote                  3292
#        domestic_cow           15000
#        domestic_dog             113
#        elk                     3321
#        empty                  15000
#        gray_fox                1535
#        moose                   1495
#        red_fox                  258
#        vehicle                 3902
#        white_tailed_deer       2040
#        wild_turkey              655
#        wolf                      71
# Name: id, dtype: int64

# %%
shuff_df[['category_name', 'old_path', 'new_path']]
# Out:
#               category_name  \
# 0       american_black_bear
# 1       american_black_bear
# 2       american_black_bear
# 3       american_black_bear
# 4       american_black_bear
# 5       american_black_bear
# 6       american_black_bear
# 7       american_black_bear
# 8       american_black_bear
# 9       american_black_bear
# 10      american_black_bear
# 11      american_black_bear
# 12      american_black_bear
# 13      american_black_bear
# 14      american_black_bear
# 15      american_black_bear
# 16      american_black_bear
# 17      american_black_bear
# 18      american_black_bear
# 19      american_black_bear
# 20      american_black_bear
# 21      american_black_bear
# 22      american_black_bear
# 23      american_black_bear
# 24      american_black_bear
# 25      american_black_bear
# 26      american_black_bear
# 27      american_black_bear
# 28      american_black_bear
# 29      american_black_bear
# ...                     ...
# 439858                 wolf
# 439859                 wolf
# 439860                 wolf
# 439861                 wolf
# 439862                 wolf
# 439863                 wolf
# 439864                 wolf
# 439865                 wolf
# 439866                 wolf
# 439867                 wolf
# 439868                 wolf
# 439869                 wolf
# 439870                 wolf
# 439871                 wolf
# 439872                 wolf
# 439873                 wolf
# 439874                 wolf
# 439875                 wolf
# 439876                 wolf
# 439877                 wolf
# 439878                 wolf
# 439879                 wolf
# 439880                 wolf
# 439881                 wolf
# 439882                 wolf
# 439883                 wolf
# 439884                 wolf
# 439885                 wolf
# 439886                 wolf
# 439887                 wolf
#
#                                                  old_path  \
# 0                   /data/nacti/sub343/WA-Site1_11628.JPG
# 1                   /data/nacti/sub343/WA-Site2_00550.JPG
# 2                   /data/nacti/sub348/WA-Site5_01340.JPG
# 3       /data/nacti/sub039/CA-04_05_04_2016_CA-04_0013...
# 4       /data/nacti/sub041/CA-04_10_31_2016_CA-04_0025...
# 5                   /data/nacti/sub346/WA-Site2_31369.JPG
# 6       /data/nacti/sub037/CA-03_06_07_2016_CA-03_0021...
# 7                   /data/nacti/sub347/WA-Site3_04901.JPG
# 8                   /data/nacti/sub350/WA-Site9_01445.JPG
# 9       /data/nacti/sub104/CA-42_12_02_2015_CA-42_0012...
# 10      /data/nacti/sub008/2010_Unit177_Ivan019_img011...
# 11                  /data/nacti/sub345/WA-Site2_23388.JPG
# 12      /data/nacti/sub006/2010_Unit170_Ivan045_img023...
# 13                  /data/nacti/sub344/WA-Site2_06468.JPG
# 14      /data/nacti/sub104/CA-42_09_02_2016_CA-42_0020...
# 15      /data/nacti/sub032/2016_Unit130_Ivan015_img062...
# 16      /data/nacti/sub040/CA-04_08_12_2015_CA-04_0008...
# 17                  /data/nacti/sub349/WA-Site7_01689.JPG
# 18                  /data/nacti/sub350/WA-Site8_02922.JPG
# 19      /data/nacti/sub003/2010_Unit157_Ivan039_img084...
# 20      /data/nacti/sub104/CA-42_10_06_2016_CA-42_0021...
# 21                  /data/nacti/sub345/WA-Site2_18481.JPG
# 22      /data/nacti/sub091/CA-34_08_04_2015_CA-34_0016...
# 23                 /data/nacti/sub341/WA-Site10_08292.JPG
# 24                  /data/nacti/sub345/WA-Site2_21087.JPG
# 25      /data/nacti/sub041/CA-05_08_01_2016_CA-05_0005...
# 26      /data/nacti/sub047/CA-10_09_07_2016_CA-10_0025...
# 27                  /data/nacti/sub344/WA-Site2_14302.JPG
# 28                  /data/nacti/sub343/WA-Site2_04750.JPG
# 29      /data/nacti/sub099/CA-39_07_12_2016_CA-39_0014...
# ...                                                   ...
# 439858  /data/nacti/sub107/CA-43_09_02_2016_CA-43_0028...
# 439859  /data/nacti/sub107/CA-43_09_02_2016_CA-43_0028...
# 439860  /data/nacti/sub298/FL-38_04_05_2016_FL-38_0031...
# 439861  /data/nacti/sub298/FL-38_03_07_2016_FL-38_0029...
# 439862  /data/nacti/sub095/CA-38_04_02_2015_CA-38_0000...
# 439863  /data/nacti/sub109/CA-45_03_30_2015_CA-45_0000...
# 439864  /data/nacti/sub057/CA-17_09_18_2015_CA-17_0024...
# 439865  /data/nacti/sub075/CA-28_09_18_2015_CA-28_0012...
# 439866  /data/nacti/sub097/CA-38_08_17_2015_CA-38_0021...
# 439867  /data/nacti/sub095/CA-38_04_02_2015_CA-38_0000...
# 439868  /data/nacti/sub045/CA-09_09_15_2015_CA-09_0003...
# 439869  /data/nacti/sub298/FL-38_04_05_2016_FL-38_0032...
# 439870  /data/nacti/sub113/CA-48_09_11_2015_CA-48_0004...
# 439871  /data/nacti/sub095/CA-38_04_02_2015_CA-38_0000...
# 439872  /data/nacti/sub113/CA-48_08_12_2015_CA-48_0002...
# 439873  /data/nacti/sub107/CA-43_09_02_2016_CA-43_0028...
# 439874  /data/nacti/sub095/CA-38_04_02_2015_CA-38_0000...
# 439875  /data/nacti/sub057/CA-17_09_18_2015_CA-17_0024...
# 439876  /data/nacti/sub057/CA-17_09_18_2015_CA-17_0024...
# 439877  /data/nacti/sub061/CA-18_09_18_2015_CA-18_0019...
# 439878  /data/nacti/sub057/CA-17_09_18_2015_CA-17_0024...
# 439879  /data/nacti/sub235/FL-21_07_06_2016_FL-21_0029...
# 439880  /data/nacti/sub057/CA-17_09_18_2015_CA-17_0024...
# 439881  /data/nacti/sub098/CA-38_09_10_2015_CA-38_0022...
# 439882  /data/nacti/sub298/FL-38_03_07_2016_FL-38_0029...
# 439883  /data/nacti/sub153/FL-06_06_02_2016_FL-06_0029...
# 439884  /data/nacti/sub057/CA-17_09_18_2015_CA-17_0024...
# 439885  /data/nacti/sub057/CA-17_09_18_2015_CA-17_0024...
# 439886  /data/nacti/sub057/CA-17_09_18_2015_CA-17_0024...
# 439887  /data/nacti/sub057/CA-17_09_18_2015_CA-17_0024...
#
#                                                  new_path
# 0       /data/training_data/train/american_black_bear/...
# 1       /data/training_data/train/american_black_bear/...
# 2       /data/training_data/train/american_black_bear/...
# 3       /data/training_data/train/american_black_bear/...
# 4       /data/training_data/train/american_black_bear/...
# 5       /data/training_data/train/american_black_bear/...
# 6       /data/training_data/train/american_black_bear/...
# 7       /data/training_data/train/american_black_bear/...
# 8       /data/training_data/train/american_black_bear/...
# 9       /data/training_data/train/american_black_bear/...
# 10      /data/training_data/train/american_black_bear/...
# 11      /data/training_data/train/american_black_bear/...
# 12      /data/training_data/train/american_black_bear/...
# 13      /data/training_data/train/american_black_bear/...
# 14      /data/training_data/train/american_black_bear/...
# 15      /data/training_data/train/american_black_bear/...
# 16      /data/training_data/train/american_black_bear/...
# 17      /data/training_data/train/american_black_bear/...
# 18      /data/training_data/train/american_black_bear/...
# 19      /data/training_data/train/american_black_bear/...
# 20      /data/training_data/train/american_black_bear/...
# 21      /data/training_data/train/american_black_bear/...
# 22      /data/training_data/train/american_black_bear/...
# 23      /data/training_data/train/american_black_bear/...
# 24      /data/training_data/train/american_black_bear/...
# 25      /data/training_data/train/american_black_bear/...
# 26      /data/training_data/train/american_black_bear/...
# 27      /data/training_data/train/american_black_bear/...
# 28      /data/training_data/train/american_black_bear/...
# 29      /data/training_data/train/american_black_bear/...
# ...                                                   ...
# 439858  /data/training_data/test/wolf/CA-43_09_02_2016...
# 439859  /data/training_data/test/wolf/CA-43_09_02_2016...
# 439860  /data/training_data/test/wolf/FL-38_04_05_2016...
# 439861  /data/training_data/test/wolf/FL-38_03_07_2016...
# 439862  /data/training_data/test/wolf/CA-38_04_02_2015...
# 439863  /data/training_data/test/wolf/CA-45_03_30_2015...
# 439864  /data/training_data/test/wolf/CA-17_09_18_2015...
# 439865  /data/training_data/test/wolf/CA-28_09_18_2015...
# 439866  /data/training_data/test/wolf/CA-38_08_17_2015...
# 439867  /data/training_data/test/wolf/CA-38_04_02_2015...
# 439868  /data/training_data/test/wolf/CA-09_09_15_2015...
# 439869  /data/training_data/test/wolf/FL-38_04_05_2016...
# 439870  /data/training_data/test/wolf/CA-48_09_11_2015...
# 439871  /data/training_data/test/wolf/CA-38_04_02_2015...
# 439872  /data/training_data/test/wolf/CA-48_08_12_2015...
# 439873  /data/training_data/test/wolf/CA-43_09_02_2016...
# 439874  /data/training_data/test/wolf/CA-38_04_02_2015...
# 439875  /data/training_data/test/wolf/CA-17_09_18_2015...
# 439876  /data/training_data/test/wolf/CA-17_09_18_2015...
# 439877  /data/training_data/test/wolf/CA-18_09_18_2015...
# 439878  /data/training_data/test/wolf/CA-17_09_18_2015...
# 439879  /data/training_data/test/wolf/FL-21_07_06_2016...
# 439880  /data/training_data/test/wolf/CA-17_09_18_2015...
# 439881  /data/training_data/test/wolf/CA-38_09_10_2015...
# 439882  /data/training_data/test/wolf/FL-38_03_07_2016...
# 439883  /data/training_data/test/wolf/FL-06_06_02_2016...
# 439884  /data/training_data/test/wolf/CA-17_09_18_2015...
# 439885  /data/training_data/test/wolf/CA-17_09_18_2015...
# 439886  /data/training_data/test/wolf/CA-17_09_18_2015...
# 439887  /data/training_data/test/wolf/CA-17_09_18_2015...
#
# [439888 rows x 3 columns]

# %%
shuff_df['set'].value_counts()/len(shuff_df)
# Out:
# train    0.700017
# val      0.150000
# test     0.149984
# Name: set, dtype: float64

# %%
for i in list(shuff_df['dir_name'].unique()):
    os.makedirs(i)

# %%
for idx, row in shuff_df.iterrows():
    copyfile(row['old_path'], row['new_path'])
